# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
who = pd.read_csv('D:/NED University/DATA VISUALIZATION (07-10-2023)/WHO.csv')

# %%
who
# Out:
#       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# 1                     1           0                  0
# ...

# %%
who.info
# Out:
# <bound method DataFrame.info of       Date_reported                           Country  New_cases  \
# 0        2020-01-04                             China          1
# 1        2020-01-05                             China          0
# 2        2020-01-06                             China          3
# 3        2020-01-07                             China          0
# 4        2020-01-08                             China          0
# ...             ...                               ...        ...
# 31871    2020-07-31                            Panama       1046
# 31872    2020-07-31                       Timor-Leste          0
# 31873    2020-07-31                         Guatemala       1221
# 31874    2020-07-31  Saint Vincent and the Grenadines          0
# 31875    2020-07-31  Democratic Republic of the Congo         79
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 0                     1           0                  0
# ...

# %%
import pandas as pd
wwho = pd.read_csv('D:/NED University/DATA VISUALIZATION (07-10-2023)/WHO.csv')

# Now you can check the 'ndim' attribute
ndim = wwho.ndim
print(ndim)
# Out:
# 2

# %%
import pandas as pd
who = pd.read_csv('D:/NED University/DATA VISUALIZATION (07-10-2023)/WHO.csv')

# Use the 'head()' method to display the first 20 rows
who.head(5)
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
who["Date_reported"]
# Out:
# 0        2020-01-04
# 1        2020-01-05
# 2        2020-01-06
# 3        2020-01-07
# 4        2020-01-08
#             ...
# 31871    2020-07-31
# 31872    2020-07-31
# 31873    2020-07-31
# 31874    2020-07-31
# 31875    2020-07-31
# Name: Date_reported, Length: 31876, dtype: object

# %%
who.Date_reported
# Out:
# 0        2020-01-04
# 1        2020-01-05
# 2        2020-01-06
# 3        2020-01-07
# 4        2020-01-08
#             ...
# 31871    2020-07-31
# 31872    2020-07-31
# 31873    2020-07-31
# 31874    2020-07-31
# 31875    2020-07-31
# Name: Date_reported, Length: 31876, dtype: object

# %%
pd.to_datetime(who["Date_reported"])
# Out:
# 0       2020-01-04
# 1       2020-01-05
# 2       2020-01-06
# 3       2020-01-07
# 4       2020-01-08
#            ...
# 31871   2020-07-31
# 31872   2020-07-31
# 31873   2020-07-31
# 31874   2020-07-31
# 31875   2020-07-31
# Name: Date_reported, Length: 31876, dtype: datetime64[ns]

# %%
who[["Date_reported", "Cumulative_cases"]]
# Out:
#       Date_reported  Cumulative_cases
# 0        2020-01-04                 1
# 1        2020-01-05                 1
# 2        2020-01-06                 4
# 3        2020-01-07                 4
# 4        2020-01-08                 4
# ...             ...               ...
# 31871    2020-07-31             63269
# 31872    2020-07-31                24
# 31873    2020-07-31             48826
# 31874    2020-07-31                52
# 31875    2020-07-31              9009
#
# [31876 rows x 2 columns]

# %%
who.Country.unique()
# Out:
# array(['China', 'Thailand', 'Japan', 'Republic of Korea',
#        'United States of America', 'Singapore', 'Nepal', 'France',
#        'Viet Nam', 'Malaysia', 'Australia', 'Canada', 'Sri Lanka',
#        'Cambodia', 'Germany', 'Italy', 'Finland', 'United Arab Emirates',
#        'India', 'Philippines', 'Sweden', 'Russian Federation',
#        'The United Kingdom', 'Spain', 'Belgium', 'Other', 'Egypt',
#        'Iran (Islamic Republic of)', 'Israel', 'Lebanon', 'Oman',
#        'Bahrain', 'Switzerland', 'Iraq', 'Afghanistan', 'Kuwait',
#        'Algeria', 'Austria', 'Romania', 'Norway', 'North Macedonia',
#        'Croatia', 'Georgia', 'Pakistan', 'Brazil', 'Denmark', 'Greece',
#        'Estonia', 'Nigeria', 'Lithuania', 'New Zealand', 'Mexico',
#        'Netherlands', 'San Marino', 'Ecuador', 'Monaco', 'Qatar',
#        'Azerbaijan', 'Belarus', 'Armenia', 'Czechia', 'Ireland',
#        'Iceland', 'Luxembourg', 'Morocco', 'Saint Barthélemy', 'Portugal',
# ...

# %%
Pakistan = who.Country == "Pakistan".title()

# %%
Pakistan
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31871    False
# 31872    False
# 31873    False
# 31874    False
# 31875    False
# Name: Country, Length: 31876, dtype: bool

# %%
who[Pakistan]
# Out:
#       Date_reported   Country  New_cases  Cumulative_cases  New_deaths  \
# 898      2020-02-26  Pakistan          6                 6           0
# 910      2020-02-27  Pakistan          0                 6           0
# 995      2020-02-28  Pakistan          0                 6           0
# 1022     2020-02-29  Pakistan          2                 8           0
# 1113     2020-03-01  Pakistan          0                 8           0
# ...             ...       ...        ...               ...         ...
# 30882    2020-07-27  Pakistan       1176            274289          20
# 31051    2020-07-28  Pakistan        936            275225          23
# 31392    2020-07-29  Pakistan       1063            276288          27
# 31586    2020-07-30  Pakistan       1114            277402          32
# 31831    2020-07-31  Pakistan        903            278305          27
#
#        Cumulative_deaths
# 898                    0
# 910                    0
# 995                    0
# ...

# %%
Italy = who.Country == "Italy"

# %%
who[Italy]
# Out:
#       Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 123      2020-01-29   Italy          6                 6           0
# 144      2020-01-30   Italy          0                 6           0
# 158      2020-01-31   Italy          0                 6           0
# 187      2020-02-01   Italy          0                 6           0
# 215      2020-02-02   Italy          0                 6           0
# ...             ...     ...        ...               ...         ...
# 30870    2020-07-27   Italy        254            246118           5
# 31097    2020-07-28   Italy        168            246286           5
# 31333    2020-07-29   Italy        202            246488          11
# 31629    2020-07-30   Italy        288            246776           6
# 31686    2020-07-31   Italy        382            247158           3
#
#        Cumulative_deaths
# 123                    0
# 144                    0
# 158                    0
# 187                    0
# ...

# %%
import plotly.express as px

# %%
dir(px)
# Out:
# ['Constant',
#  'IdentityMap',
#  'NO_COLOR',
#  'Range',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_chart_types',
#  '_core',
#  '_doc',
#  '_imshow',
#  '_special_inputs',
#  'absolute_import',
#  'area',
#  'bar',
#  'bar_polar',
#  'box',
#  'choropleth',
#  'choropleth_mapbox',
#  'colors',
#  'data',
#  'defaults',
#  'density_contour',
#  'density_heatmap',
#  'density_mapbox',
#  'ecdf',
#  'funnel',
#  'funnel_area',
#  'get_trendline_results',
#  'histogram',
#  'icicle',
#  'imshow',
#  'imshow_utils',
#  'line',
#  'line_3d',
#  'line_geo',
#  'line_mapbox',
#  'line_polar',
#  'line_ternary',
#  'optional_imports',
#  'parallel_categories',
#  'parallel_coordinates',
#  'pd',
#  'pie',
#  'scatter',
#  'scatter_3d',
#  'scatter_geo',
#  'scatter_mapbox',
#  'scatter_matrix',
#  'scatter_polar',
#  'scatter_ternary',
#  'set_mapbox_access_token',
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# time (t), carrying capacity (K), growth rate (r), and initial population (P0) as parameters.
# Logistic growth function
def logistic_growth(t, K, r, P0):
    return K / (1 + (K / P0 - 1) * np.exp(-r * t))

# Parameters for the logistic growth
K = 1000  # Carrying capacity or the maximum population
r = 0.1   # Growth rate
P0 = 10   # Initial population

# Generate time values from 0 to 100 (you can adjust this range)
t = np.linspace(0, 100, 100)

# Calculate population at each time point
population = logistic_growth(t, K, r, P0)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(t, population, label='Logistic Growth')
plt.xlabel('Time')
plt.ylabel('Population')
plt.title('Logistic Growth Model')
plt.axvline(x=50, color='r', linestyle='--', label='Inflection Point')
plt.legend()
plt.grid(True)
plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# Parameters for exponential growth
r = 0.1  # Growth rate
N0 = 1   # Initial population
t_max = 10  # Maximum time period

# Generate time values from 0 to t_max
t = np.linspace(0, t_max, 100)

# Calculate population at each time point using the exponential growth formula
population = N0 * np.exp(r * t)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(t, population, label='Exponential Growth')
plt.xlabel('Time')
plt.ylabel('Population')
plt.title('Exponential Growth Model')
plt.legend()
plt.grid(True)
plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# We define parameters for linear growth: the growth rate (slope), initial value (intercept), and the maximum time period (t_max).
# We generate a range of time values using NumPy's linspace().
# We calculate the quantity at each time point using the linear growth formula, which is Quantity(t) = slope * t + intercept.



# Parameters for linear growth
slope = 2  # Linear growth rate
intercept = 10  # Initial value
t_max = 10  # Maximum time period

# Generate time values from 0 to t_max
t = np.linspace(0, t_max, 100)

# Calculate the linear growth at each time point
growth = slope * t + intercept

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(t, growth, label='Linear Growth')
plt.xlabel('Time')
plt.ylabel('Quantity')
plt.title('Linear Growth Model')
plt.legend()
plt.grid(True)
plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# We define parameters for logarithmic growth: the limiting value K, growth rate r, and the maximum time period t_max.
# We generate a range of time values using NumPy's linspace().
# We calculate the quantity at each time point using the logarithmic growth formula, which is Quantity(t) = K * (1 - e^(-r * t)).

# Parameters for logarithmic growth
K = 100  # Limiting value or maximum value
r = 0.1  # Growth rate
t_max = 50  # Maximum time period

# Generate time values from 0 to t_max
t = np.linspace(0, t_max, 100)

# Calculate the quantity at each time point using the logarithmic growth formula
quantity = K * (1 - np.exp(-r * t))

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(t, quantity, label='Logarithmic Growth')
plt.xlabel('Time')
plt.ylabel('Quantity')
plt.title('Logarithmic Growth Model')
plt.legend()
plt.grid(True)
plt.show()
